# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishant-172-bot/Samsung-Innovation-Campus/blob/main/SIC_DAY_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={'col1':[1,2,3,4],'col2':[6,7,8,9]}
df=pd.DataFrame(data)
print(df)
# Out:
#    col1  col2
# 0     1     6
# 1     2     7
# 2     3     8
# 3     4     9

# %%
df.index=["new0","new1","new2","new3"]
print(df)
# Out:
#       col1  col2
# new0     1     6
# new1     2     7
# new2     3     8
# new3     4     9

# %%
df.columns=["col:1","col:2"]
print(df)
# Out:
#       col:1  col:2
# new0      1      6
# new1      2      7
# new2      3      8
# new3      4      9

# %%
df.rename(index={"new0":"0"},inplace=True)
df
# Out:
#       col:1  col:2
# 0         1      6
# new1      2      7
# new2      3      8
# new3      4      9

# %%
print(df.rename(columns={"col:2":"new col2"}))
# Out:
#       col:1  new col2
# new0      1         6
# new1      2         7
# new2      3         8
# new3      4         9

# %%
import numpy as np
n=np.arange(10,16)
ss=pd.Series(n,index=["a","c","d","d","e","f",])

# %%
dic_data={"one":ss,"two":ss}
pd.DataFrame.from_dict(dic_data,orient='columns')
# Out:
#    one  two
# a   10   10
# c   11   11
# d   12   12
# d   13   13
# e   14   14
# f   15   15

# %%
pd.DataFrame.from_dict(dic_data,orient='index')
# Out:
#       a   c   d   e   f
# one  10  11  13  14  15
# two  10  11  13  14  15

# %%
pd.DataFrame.from_dict(dic_data,orient='index',columns=["A","B","C","D","E"])
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
#read_csv,read_jaon,read_xml -> to_csv,to_json,to_xml
#/images/pic.jpg -> root bata, images/pic.jpg -> same directory ko images folder ma

# %%
df =pd.DataFrame({"alphabet":["A","B","C","D","E","a","c","d","e","f"]})
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2408970912.py in <cell line: 0>()
# ----> 1 df =pd.DataFrame({"alphabet":["A","B","C","D","E","a","c","d","e","f"]},index_col='alphabet')
#       2 df
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'index_col'

# %%
df.head()
# Out:
#   alphabet
# 0        A
# 1        B
# 2        C
# 3        D
# 4        E

# %%
df.head(-3)
# Out:
#   alphabet
# 0        A
# 1        B
# 2        C
# 3        D
# 4        E
# 5        a
# 6        c

# %%
df.tail(-3)
# Out:
#   alphabet
# 3        D
# 4        E
# 5        a
# 6        c
# 7        d
# 8        e
# 9        f

# %%
df.shape
# Out:
# (10, 1)

# %%
len(df)
# Out:
# 10

# %%
df.columns,df.values
# Out:
# (Index(['alphabet'], dtype='object'),
#  array([['A'],
#         ['B'],
#         ['C'],
#         ['D'],
#         ['E'],
#         ['a'],
#         ['c'],
#         ['d'],
#         ['e'],
#         ['f']], dtype=object))

# %%
titanic=pd.read_csv(r"/Titanic-Dataset.csv")   #header = none if header is missing
# index_col=Name to replace the index with the name column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
world=pd.read_json("/universities_ranking.json",orient='records')
world
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
world.describe()
# Out:
#            ranking  students staff ratio
# count  1526.000000           1526.000000
# mean    763.500000             18.778571
# std     440.662569             13.818076
# min       1.000000              0.900000
# 25%     382.250000             12.200000
# 50%     763.500000             16.100000
# 75%    1144.750000             21.875000
# max    1526.000000            339.100000

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ranking               1526 non-null   int64
#  1   title                 1526 non-null   object
#  2   location              1526 non-null   object
#  3   number students       1526 non-null   object
#  4   students staff ratio  1526 non-null   float64
#  5   perc intl students    1526 non-null   object
#  6   gender ratio          1526 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 83.6+ KB

# %%
world.drop([0,1,2,3], axis=0, inplace=False) #axis=0 -> rows
# Out:
#       ranking                                           title        location  \
# 4           5           Massachusetts Institute of Technology   United States
# 5           6                         University of Cambridge  United Kingdom
# 6           7              University of California, Berkeley   United States
# 7           8                                 Yale University   United States
# 8           9                            Princeton University   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
world.drop(["students staff ratio"], axis=1, inplace=False) #axis=1 -> columns
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
index_pos=world.iloc[5:10]
index_pos
# Out:
#    ranking                               title        location  \
# 5        6             University of Cambridge  United Kingdom
# 6        7  University of California, Berkeley   United States
# 7        8                     Yale University   United States
# 8        9                Princeton University   United States
# 9       10           The University of Chicago   United States
#
#   number students  students staff ratio perc intl students gender ratio
# 5          19,370                  11.0                38%      47 : 53
# 6          39,918                  19.8                17%      51 : 49
# 7          12,910                   6.0                20%      50 : 50
# 8           8,091                   8.0                23%      46 : 54
# 9          14,292                   5.9                31%      46 : 54

# %%
# Creating the DataFrame
df = pd.DataFrame({'Weight': [45, 88, 56, 15, 71],
                   'Name': ['Sam', 'Andrea', 'Alex', 'Robin', 'Kia'],
                   'Age': [14, 25, 55, 8, 21]})

# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

# Set the index
df.index = index_

# Print the DataFrame
print("Original DataFrame:")
print(df)

# Corrected selection using loc for a specific cell
result = df.loc['Row_2']

print(result)
# Out:
# Original DataFrame:
#        Weight    Name  Age
# Row_1      45     Sam   14
# Row_2      88  Andrea   25
# Row_3      56    Alex   55
# Row_4      15   Robin    8
# Row_5      71     Kia   21
# Weight        88
# Name      Andrea
# Age           25
# Name: Row_2, dtype: object

# %%
world
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
# ...

# %%
result=world.loc['location','Nepal']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nepal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-211005901.py in <cell line: 0>()
# ----> 1 result=world.loc['location','Nepal']
#
# ...

# %%
nepal_universities = world[world['location'] == 'Nepal']
display(nepal_universities)
# Out:
#      ranking                 title location number students  \
# 982      983  Tribhuvan University    Nepal         422,690
#
#      students staff ratio perc intl students gender ratio
# 982                  31.1                 0%      51 : 49

# %%
spotify=pd.read_csv("/spotify_global_2019_most_streamed_tracks_audio_features.csv")

# %%
spotify.head()
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309      Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359          Señorita
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 3    Tones and I  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 4   Shawn Mendes  https://open.spotify.com/track/6v3KW9xbzN5yKLt...
#
#    acousticness  danceability  energy  ...  valence    tempo  time_signature  \
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            1717 non-null   object
#  1   Rank               1717 non-null   float64
#  2   Track_id           1717 non-null   object
#  3   Streams            1717 non-null   int64
#  4   Track Name         1717 non-null   object
#  5   Artist             1717 non-null   object
#  6   URL                1717 non-null   object
#  7   acousticness       1717 non-null   float64
#  8   danceability       1717 non-null   float64
#  9   energy             1717 non-null   float64
#  10  instrumentalness   1717 non-null   float64
#  11  liveness           1717 non-null   float64
#  12  loudness           1717 non-null   float64
#  13  speechiness        1717 non-null   float64
#  14  valence            1717 non-null   float64
# ...

# %%
spotify.describe()
# Out:
#               Rank       Streams  acousticness  danceability       energy  \
# count  1717.000000  1.717000e+03   1717.000000   1717.000000  1717.000000
# mean    859.000000  5.166175e+07      0.257652      0.675438     0.624354
# std     495.799523  1.047532e+08      0.256975      0.154163     0.172298
# min       1.000000  5.242300e+05      0.000037      0.151000     0.013700
# 25%     430.000000  1.763026e+06      0.051900      0.584000     0.525000
# 50%     859.000000  9.623926e+06      0.171000      0.694000     0.646000
# 75%    1288.000000  4.829352e+07      0.385000      0.787000     0.747000
# max    1717.000000  1.166186e+09      0.979000      0.974000     0.978000
#
#        instrumentalness     liveness     loudness  speechiness      valence  \
# count       1717.000000  1717.000000  1717.000000  1717.000000  1717.000000
# mean           0.014577     0.174317    -6.477624     0.129967     0.487719
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(range(100))
# Out:
# <Axes: >

# %%
spotify
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3     global     4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4     global     5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ...      ...     ...                     ...         ...
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j      554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP      544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM      536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc      524230
#
#                                              Track Name              Artist  \
# 0                                      Sweet but Psycho             Ava Max
# 1                                               bad guy       Billie Eilish
# ...

# %%
nepali=spotify[spotify["Country"]=="Nepal"]
nepali
# Out:
# Empty DataFrame
# Columns: [Country, Rank, Track_id, Streams, Track Name, Artist, URL, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, valence, tempo, time_signature, duration_ms, key, mode, Artist_id, Artist_popularity, Artist_follower, Artist_img]
# Index: []
#
# [0 rows x 24 columns]

# %%
df=spotify[["Rank","Artist","Streams","Artist_popularity",'danceability',"energy","Track Name"]]
df
# Out:
#         Rank              Artist     Streams  Artist_popularity  danceability  \
# 0        1.0             Ava Max  1166185736                 87         0.719
# 1        2.0       Billie Eilish  1052358787                 98         0.701
# 2        3.0       Ariana Grande   789094044                 97         0.778
# 3        4.0         Tones and I   764208309                 92         0.825
# 4        5.0        Shawn Mendes   763064359                 94         0.759
# ...      ...                 ...         ...                ...           ...
# 1712  1713.0                 Sia      554971                 90         0.628
# 1713  1714.0                  LX      544655                 71         0.764
# 1714  1715.0            Bee Gees      536886                 79         0.708
# 1715  1716.0    MC Kevin o Chris      536447                 84         0.896
# 1716  1717.0  Henrique & Juliano      524230                 84         0.690
#
# ...

# %%
pop_song=df[df['Artist_popularity']>95]
pop_song
# Out:
#         Rank         Artist     Streams  Artist_popularity  danceability  \
# 1        2.0  Billie Eilish  1052358787                 98         0.701
# 2        3.0  Ariana Grande   789094044                 97         0.778
# 9       10.0    Post Malone   615519053                100         0.833
# 13      14.0    Post Malone   501130662                100         0.580
# 14      15.0     Ed Sheeran   499741532                 98         0.640
# ...      ...            ...         ...                ...           ...
# 1619  1620.0     The Weeknd      729029                 96         0.580
# 1656  1657.0          Drake      699242                 99         0.508
# 1669  1670.0      Bad Bunny      685308                 98         0.853
# 1672  1673.0          Drake      684206                 99         0.643
# 1689  1690.0          Drake      669961                 99         0.505
#
#       energy                       Track Name
# ...

# %%
playlist=pop_song[pop_song["Artist"]=='Post Malone']
playlist
# Out:
#         Rank       Artist    Streams  Artist_popularity  danceability  energy  \
# 9       10.0  Post Malone  615519053                100         0.833   0.539
# 13      14.0  Post Malone  501130662                100         0.580   0.653
# 25      26.0  Post Malone  428712946                100         0.695   0.762
# 31      32.0  Post Malone  405953336                100         0.680   0.578
# 33      34.0  Post Malone  395449434                100         0.585   0.520
# 112    113.0  Post Malone  209280692                100         0.755   0.522
# 125    126.0  Post Malone  195603663                100         0.750   0.560
# 173    174.0  Post Malone  153232549                100         0.499   0.800
# 191    192.0  Post Malone  142006864                100         0.630   0.804
# 227    228.0  Post Malone  118147209                100         0.617   0.684
# 229    230.0  Post Malone  116832184                100         0.556   0.538
# ...

# %%
import matplotlib.pyplot as plt
x=pop_song["energy"]
y=pop_song["danceability"]
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: xlabel='energy', ylabel='danceability'>

# %%
uni=pop_song["Artist"].unique()
uni
# Out:
# array(['Ava Max', 'Daddy Yankee', 'Marshmello', 'Pedro Capó',
#        'Post Malone', 'Ed Sheeran', 'Lil Nas X', 'Anuel AA', 'Bad Bunny',
#        'Panic! At The Disco', 'Travis Scott', 'Ariana Grande',
#        'benny blanco', 'Lizzo', 'Mabel', 'Sam Smith', 'MEDUZA', 'Sech',
#        'Jhay Cortez', 'ROSALÍA', 'XXXTENTACION', 'Lauv', 'DJ Snake',
#        'J Balvin', 'A Boogie Wit da Hoodie', 'Imagine Dragons',
#        '5 Seconds of Summer', 'Jonas Brothers', 'Ozuna', 'Lunay',
#        'Anne-Marie', 'Queen', 'Nicky Jam', 'Maluma', 'Calvin Harris',
#        'Lil Baby', 'DaBaby', 'Dynoro', 'DJ Luian', 'BTS', 'YNW Melly',
#        'Katy Perry', 'Paulo Londra', 'Kygo', 'Shawn Mendes',
#        'Ellie Goulding', 'Kodak Black', 'Cardi B', 'Regard', 'Dua Lipa',
#        'The Black Eyed Peas', 'Piso 21', 'Tainy', '21 Savage',
#        'Arizona Zervas', 'OneRepublic', 'Dalex', 'Camilo', 'Loud Luxury',
#        'Dan + Shay', 'Sheck Wes', 'Lil Tecca', 'Mau y Ricky',
# ...

# %%
plt.figure()
sns.heatmap(x, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3035421060.py in <cell line: 0>()
#       1 plt.figure()
# ----> 2 sns.heatmap(x, annot=True)
#       3 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...
