# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishant-172-bot/Samsung-Innovation-Campus/blob/main/SIC_DAY_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chart
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chart: filename=chart-0.2.3-py3-none-any.whl size=6934 sha256=93545bc7bf6ebed56faa966c890a9500c71e1dfe3b2a4cc10ef99f965ddc0fd0
#   Stored in directory: /root/.cache/pip/wheels/97/5c/ca/560d1e1fde1790895dea6e2d4b871134eab8e16d2e697a9236
# Successfully built chart
# ...

# %%
import chart

# %%
x=[1,3,54,23,6,8,9,10]

# %%
chart.histogram(x)
# Out:
# ▇
# ▇
# ▇
# ▇
# ▇
# ▇
# ▇
# ▇
# ▇   ▇   ▇
# ▇   ▇   ▇

# %%
import math   #need to use math. to access

# %%
math.sin(10)
# Out:
# -0.5440211108893698

# %%
from math import *  #no need for math.

# %%
sin(9)
# Out:
# 0.4121184852417566

# %%
import random

# %%
print(random.sample(x,4))
print(random.choice(x))
# Out:
# [3, 10, 6, 9]
# 6

# %%
random.random() #0-1
# Out:
# 0.8603792542594004

# %%
random.randint(1,10)
# Out:
# 1

# %%
import time

# %%
time.time()   #from unix epoch
# Out:
# 1769654267.370275

# %%
print(time.ctime())
time.sleep(2)

# %%
time.strftime("%a, %d")
# Out:
# 'Thu, 29'

# %%
from time import gmtime, strftime, localtime

# %%
time.strftime("%a, %d",localtime())
# Out:
# 'Thu, 29'

# %%
import datetime as dt

# %%
today=dt.date.today()
print(today)
print(today.month)
# Out:
# 2026-01-29
# 1

# %%
dt.UTC
# Out:
# datetime.timezone.utc

# %%
from datetime import timedelta as td

# %%
d=dt.datetime(2000, 5, 3)
delta=dt.timedelta(days=30)   #to add subtract a datetime difference yo datetime object
print(d+delta)
# Out:
# 2000-06-02 00:00:00

# %%
now=dt.datetime.now()
now
# Out:
# datetime.datetime(2026, 1, 29, 2, 46, 34, 447863)

# %%
replace=now.replace(month=10)
replace
# Out:
# datetime.datetime(2026, 10, 29, 2, 46, 34, 447863)

# %%
d=dt.datetime(2000, 5, 3)
delta=dt.timedelta(days=100)
print("Anniversary Date: ",(d+delta))
# Out:
# Anniversary Date:  2000-08-11 00:00:00
